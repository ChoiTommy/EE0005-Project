# %% [markdown]
# # Exploratory Analysis
#
# ---

# %% [markdown]
# ## Initialization

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
jobData = pd.read_csv('Datasets/cleaned_data.csv')

# %% [markdown]
# ## Data overview

# %%
jobData.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#      department salary_range  \
# 0     Marketing            0
# 1       Success            0
# 2  NODEPARTMENT            0
# 3         Sales            0
# 4  NODEPARTMENT            0
#
#                                      company_profile  \
# 0  We're Food52, and we've created a groundbreaki...
# 1  90 Seconds, the worlds Cloud Video Production ...
# 2  Valor Services provides Workforce Solutions th...
# 3  Our passion for improving quality of life thro...
# 4  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# 2  Our client, located in Houston, is actively se...
# 3  THE COMPANY: ESRI – Environmental Systems Rese...
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...
#
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
# 3  EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4  QUALIFICATIONS:RN license in the State of Texa...
#
#                                             benefits  telecommuting  ...  \
# 0                                         NOBENEFITS          False  ...
# 1  What you will get from usThrough being part of...          False  ...
# 2                                         NOBENEFITS          False  ...
# 3  Our culture is anything but corporate—we have ...          False  ...
# 4                              Full Benefits Offered          False  ...
#
#    country_code_is_TW  country_code_is_UA  country_code_is_UG  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    country_code_is_US  country_code_is_VI  country_code_is_VN  \
# 0                True               False               False
# 1               False               False               False
# 2                True               False               False
# 3                True               False               False
# 4                True               False               False
#
#    country_code_is_ZA  country_code_is_ZM  country_code  \
# 0               False               False            US
# 1               False               False            NZ
# 2               False               False            US
# 3               False               False            US
# 4               False               False            US
#
#                                 lemmatized_documents
# 0  marketing intern marketing food52 create groun...
# 1  customer service - cloud video production succ...
# 2  commission machinery assistant cma nodepartmen...
# 3  account executive - washington dc sale passion...
# 4  bill review manager nodepartment spotsource so...
#
# [5 rows x 310 columns]

# %%
jobData.dtypes
# Out:
# job_id                   int64
# title                   object
# location                object
# department              object
# salary_range            object
#                          ...
# country_code_is_VN        bool
# country_code_is_ZA        bool
# country_code_is_ZM        bool
# country_code            object
# lemmatized_documents    object
# Length: 310, dtype: object

# %%
jobData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Columns: 310 entries, job_id to lemmatized_documents
# dtypes: bool(292), int64(3), object(15)
# memory usage: 7.4+ MB

# %% [markdown]
# ## `employment_type`

# %%
jobData['fraudulent'].describe()
# Out:
# count     17880
# unique        2
# top       False
# freq      17014
# Name: fraudulent, dtype: object

# %%
jobData['employment_type'] = jobData['employment_type'].fillna('Not Specified')

# %%
sb.countplot(x = 'fraudulent', hue = 'employment_type', data = jobData)
# Out:
# <AxesSubplot:xlabel='fraudulent', ylabel='count'>

# %% [markdown]
# From this we can tell most fake jobs posted are full-time or with employment type not specified.

# %% [markdown]
# ## `has_questions` and `has_company_logo`
#
# In the following sections, we will be looking into some of the characteristics that differentiate fake job postings from the legitimate ones.
#
# ### How many of the fake postings have a recruitment process?
#
# When analysing the relationship between fraudulent postings and their recruitment process, we discovered that a large percentage of fake job postings hire without holding an interview.
#
# > 71% of fake postings hire without any recruitment process
#
# The plot below shows that 71% of the fraudulent postings hire were being offered without an interview to screen the applicants. The purpose of such listings is usually to scam the applicants and to gather their personal and financial data. As such, it makes sense that the scammers would make the barrier of entry for applicants low to attract more people to apply.

# %%
fakepostings = jobData[jobData.fraudulent == 1]
fakepostings.head()
# Out:
#      job_id                              title  \
# 98       99                    IC&E Technician
# 144     145                       Forward Cap.
# 173     174  Technician Instrument & Controls
# 180     181                    Sales Executive
# 215     216            IC&E Technician Mt Poso
#
#                                location            department  salary_range  \
# 98                    US, , Stocton, CA          Oil & Energy  95000-115000
# 144                                  NS          NODEPARTMENT             0
# 173                                  US  Power Plant & Energy             0
# 180                     PK, SD, Karachi                 Sales             0
# 215  US, CA, Bakersfield, CA / Mt. Poso          Oil & Energy  95000-115000
#
#                                        company_profile  \
# 98                                                 ...
# 144                                   NOCOMPANYPROFILE
# 173  Edison International and Refined Resources hav...
# 180                                   NOCOMPANYPROFILE
# 215                                                ...
#
#                                            description  \
# 98   IC&amp;E Technician | Bakersfield, CA Mt. Poso...
# 144  The group has raised a fund for the purchase o...
# 173  Technician Instrument &amp; ControlsLocation D...
# 180                                    Sales Executive
# 215  IC&amp;E Technician | Bakersfield, CA Mt. Poso...
#
#                                           requirements  \
# 98   QualificationsKnowledge, Skills &amp; Abilitie...
# 144                                     NOREQUIREMENTS
# 173  JOB QUALIFICATIONS-Ability to understand proce...
# 180                                    Sales Executive
# 215   QualificationsKnowledge, Skills &amp; Abiliti...
#
#                                               benefits  telecommuting  ...  \
# 98   BENEFITSWhat is offered:Competitive compensati...          False  ...
# 144                                         NOBENEFITS          False  ...
# 173  we are a team of almost 8,000 employees who he...          False  ...
# 180                                    Sales Executive          False  ...
# 215  BENEFITSWhat is offered:Competitive compensati...          False  ...
#
#      country_code_is_TW  country_code_is_UA  country_code_is_UG  \
# 98                False               False               False
# 144               False               False               False
# 173               False               False               False
# 180               False               False               False
# 215               False               False               False
#
#      country_code_is_US  country_code_is_VI  country_code_is_VN  \
# 98                 True               False               False
# 144               False               False               False
# 173                True               False               False
# 180               False               False               False
# 215                True               False               False
#
#      country_code_is_ZA  country_code_is_ZM  country_code  \
# 98                False               False            US
# 144               False               False            NS
# 173               False               False            US
# 180               False               False            PK
# 215               False               False            US
#
#                                   lemmatized_documents
# 98   ic e technician oil energy staff amp recruit d...
# 144  forward cap nodepartment nocompanyprofile grou...
# 173  technician instrument control power plant ener...
# 180  sale executive sale nocompanyprofile sale exec...
# 215  ic e technician mt poso oil energy staff amp r...
#
# [5 rows x 310 columns]

# %%
print(f"No questions: {fakepostings.has_questions[fakepostings.has_questions==False].count()}")
print(f"Has questions: {fakepostings.has_questions[fakepostings.has_questions==True].count()}")
sb.catplot( x = 'has_questions', data = fakepostings, kind="count")
# Out:
# No questions: 616
# Has questions: 250

# %% [markdown]
# ### Similarly, a large percentage of the fake postings also do not have a logo attached to the companies.
# Only 32% of the companies listed in the fake job postings have a company logo.

# %%
print(f"No logo: {fakepostings.has_company_logo[fakepostings.has_company_logo==False].count()}")
print(f"Has logo: {fakepostings.has_company_logo[fakepostings.has_company_logo==True].count()}")
sb.catplot( x = 'has_company_logo', data = fakepostings, kind="count")
# Out:
# No logo: 583
# Has logo: 283

# %% [markdown]
# ## Text exploration
#
# A lot of the fraudulent is generated from the same source. That source can generate more than 30 fake entries, all with almost the same data in certain fields. For example, one source generates over 30 fake postings for "Aptitude Staffing Solutions", all with the exact same text in the company profile field.
#
# To show this, groupby is used. First, we filter results to obtain only fraudulent results. From those fraudulent results, all entries with the same company profile, description, title, requirements, department, benefits are grouped together. From the groupby object, the counts of each group is obtained. The count shows how many fraudulent entries have the exact same text field, hence how many fake postings come from 1 the same source.

# %%
fraudData = jobData[jobData['fraudulent']==1]
fraudData.groupby('company_profile').count().sort_values('fraudulent', ascending=False)[['job_id','fraudulent']].head(20)
# Out:
#                                                     job_id  fraudulent
# company_profile
# NOCOMPANYPROFILE                                       587         587
# Aptitude Staffing Solutions has redesigned the ...      35          35
# Aker Solutions is a global provider of products...      31          31
#                                                ...      21          21
# We have aggressive growth plans in place for th...      20          20
# The Accion  story began more than 100 years ago...      16          16
# As the industry’s largest supply contracting co...      14          14
# Gary Cartwright established Cartwright Property...      12          12
# #URL_ddb080358fa5eecf5a67c649cfb4ffc343c484389f...      11          11
# Bradley Contracting Group Corporation offers a ...       7           7
# At DynCorp International it is our commitment t...       6           6
# Anthony Warren is a Marketing and Advertising c...       6           6
# NETGEAR and Aptitude Staffing Solutions have pa...       6           6
# Maynard Consulting Company has more than 20 yea...       6           6
# Bright Edge and Aptitude Staffing Solutions hav...       5           5
# Process Unlimited and Refined Resources have pa...       5           5
# Making Mobile Device Management Clear is Clearm...       5           5
# Le Meridien is situated in the heart of kuala l...       5           5
# Awarded by Expatriate Lifestyle Magazine with 2...       4           4
# Our globally connected world has forced busines...       4           4

# %%
fraudData.groupby('description').count().sort_values('job_id', ascending=False)[['job_id','fraudulent']].head(20)
# Out:
#                                                     job_id  fraudulent
# description
# We are a full-service marketing and staffing fi...      22          22
# ACCEPTING ONLINE APPLICATIONS ONLYClick Here To...      21          21
# We have several openings available in this area...      21          21
# We are seeking individuals to be connected with...      20          20
# 6* Ultra Luxury American Cruise Company is urge...      20          20
# We provide No Credit Check Financing to custome...      15          15
# We are looking for a contractors/individual who...      11          11
# Are you looking to make anywhere from 600-115,0...       9           9
# We are Seeking a candidate whose core values in...       8           8
# We have the demand. We are looking for people t...       6           6
# Payroll Clerk Job Purpose: Responsible for Comp...       6           6
# This job requires you to have the ability to op...       6           6
# - Maintain a high level of Clearmark solution e...       5           5
# Administrative AssistantEssential Job Responsib...       4           4
# Job DescriptionAdministrative AssistantDescript...       4           4
# We provide No Credit Check Financing to custome...       4           4
# Responsible for all food production including t...       4           4
# Want to work in a fast-paced, dynamic environme...       3           3
# Experienced, reliable team members are needed f...       3           3
# We are a full-service engineering, project mana...       2           2

# %%
fraudData.groupby('title').count().sort_values('job_id', ascending=False)[['job_id','fraudulent']].head(20)
# Out:
#                                                     job_id  fraudulent
# title
# Home Based Payroll Typist/Data Entry Clerks Pos...      21          21
# Cruise Staff Wanted *URGENT*                            21          21
# Data Entry Admin/Clerical Positions - Work From...      21          21
# Customer Service Representative                         17          17
# Administrative Assistant                                16          16
# Home Based Payroll Data Entry Clerk Position - ...      12          12
# Network Marketing                                       10          10
# Payroll Data Coordinator Positions - Earn $100-...      10          10
# Payroll Clerk                                           10          10
# Account Sales Managers $80-$130,000/yr                  10          10
# Data Entry                                               9           9
# Agency Sales Managers $150-$175,000/yr                   9           9
# Executive Chef                                           6           6
#  Payroll Data Entry Clerk Position - Earn $100-...       6           6
# Lawn and Maintenance Contractors                         6           6
# Call Center Representative                               6           6
# Property Preservation Field Crews                        5           5
# Call Center Representative I                             4           4
# Customer Assistant                                       4           4
# Customer Service Rep                                     4           4

# %%
fraudData.groupby('benefits').count().sort_values('job_id', ascending=False)[['job_id','fraudulent']].head(20)
# Out:
#                                                     job_id  fraudulent
# benefits
# NOBENEFITS                                             364         364
# Benefits: On board en suite accommodation and f...      21          21
# All you need is access to the Internet and you ...      21          21
# We offer• Friendly colleagues in an industry wi...      18          18
# As per job                                              11          11
# This is an entry level position and we offer fu...      10          10
# We Provide- Complete online training and office...      10          10
# This is an entry level position and we offer fu...       9           9
# Weekly pay, PTO, Paid Holidays, 401 k                    8           8
# Compensation/benefits package includes:Comprehe...       8           8
# This position is high paying and you will be pa...       6           6
# Zero start-up fee                                        6           6
# Residual Income, Travel dollars, Car Dollars, t...       6           6
# We Provide- Complete online training and office...       6           6
# 401kHealth InsurancePaid Time OffVacation TimeB...       5           5
# Totally Free To Join &amp; Suitable For All.             5           5
# Health, Dental, Life and AD&amp;D Insurance, Em...       5           5
# Residual Income, Travel dollars, Car Dollars, t...       4           4
# Benefit includes: health and welfare coverage, ...       4           4
# We offer • Friendly colleagues in an industry w...       4           4

# %%
fraudData.groupby('requirements').count().sort_values('job_id', ascending=False)[['job_id','fraudulent']].head(20)
# Out:
#                                                     job_id  fraudulent
# requirements
# NOREQUIREMENTS                                         154         154
# RequirementsAll you need is access to the Inter...      22          22
# Basic computer and typing skills, ability to sp...      21          21
# Certification &amp; Experience: Previous experi...      21          21
# Home Office SuppliesComputer with internet acce...      20          20
# Experience and Skills  Required- Minimum of 3 y...      19          19
# No any experience required.                             15          15
#  **NOTE: You must have the necessary tools for ...      11          11
# An ambition to succeed, A desire to be the best...      10          10
# Home Computer with Internet AccessBasic Compute...       8           8
# Required Tools Needed below:1. A good computer ...       6           6
# We are seeking only honest, self-motivated peop...       6           6
# Responsibilities include educating and assistin...       5           5
# Job Requirements High School Diploma or GEDPass...       5           5
# HIGH SCHOOL DIPLOMA                                      4           4
# Requirements:  At least 10+ years in software d...       3           3
# Must be able to work from home                           3           3
# Must be proficient with OutlookSome knowledge o...       3           3
# Requirements: You must have commenced either yo...       3           3
# No Experience Required And Never Any Fees.               3           3

# %%
fraudData.groupby('department').count().sort_values('job_id', ascending=False)[['job_id','fraudulent']].head(20)
# Out:
#                          job_id  fraudulent
# department
# NODEPARTMENT                531         531
# Engineering                  46          46
# Clerical                     27          27
# Oil & Energy                 24          24
# Information Technology       15          15
# Customer Service             14          14
# Administrative               14          14
# Information Technology       12          12
# Sales                        12          12
# Engineering                   9           9
# admin                         7           7
# Accounting/Payroll            6           6
# ENGINEERING                   5           5
# Sales and Research            5           5
# CALL CENTER                   5           5
# sales                         5           5
# customer service              4           4
# Account                       4           4
# Oil & Energy                  4           4
# Maintenance                   4           4

# %% [markdown]
# ### NLP model

# %%
drop_columns = ['job_id', 'salary_range', 'location', 'function', 'employment_type', 'required_experience', 'required_education', 'industry', 'department', 'description', 'requirements', 'benefits', 'title', 'company_profile', 'fraudulent', 'country_code', 'lemmatized_documents']
X_data = jobData.drop(drop_columns, axis=1)
Y_data = pd.DataFrame(jobData['fraudulent'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
#Bigram is used. It finds count of each pair words in the text. feature extraction
cv = CountVectorizer(ngram_range=(2,2))

#Vectorizer converts the list of words into a proper matrix of word counts for each word, for each data entry
X_text_data = cv.fit_transform(jobData['lemmatized_documents'])
y_text_data = jobData['fraudulent']
X_text_data
# Out:
# <17880x893991 sparse matrix of type '<class 'numpy.int64'>'
# 	with 4116089 stored elements in Compressed Sparse Row format>

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

X_text_train, X_text_test, y_text_train, y_text_test = train_test_split(X_text_data, y_text_data, test_size=0.3)
mnb = MultinomialNB()
mnb.fit(X_text_train, y_text_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
pred_text_test = pd.DataFrame(mnb.predict(X_text_test), columns=['prediction'], index=y_text_test.index)

print("Accuracy:\t", mnb.score(X_text_test, y_text_test))
print("F1 score:\t", f1_score(y_text_test, pred_text_test))
sb.heatmap(confusion_matrix(y_text_test, pred_text_test), annot=True, fmt='d')
# Out:
# Accuracy:	 0.9157345264727815
# F1 score:	 0.4840182648401827
# <AxesSubplot:>

# %% [markdown]
# ### NLP strongest predictor
#
# Uses the properties of the CountVectorizer and MNB object to find which words are the strongest predictor of being fraudulent. It calculates a ratio between 2 coefficients in the MNB model, such that the smaller the ratio, the stronger a predictor for being false.

# %%
vocab_array_words = [(x) for x, y in cv.vocabulary_.items()]
vocab_array_index = [(y) for x, y in cv.vocabulary_.items()]

# %%
feature_importance = pd.DataFrame(mnb.feature_log_prob_)
feature_importance = feature_importance.transpose()
feature_importance['words']= pd.Series(vocab_array_words, index=vocab_array_index)
feature_importance.head()
# Out:
#            0          1        words
# 0 -10.937828 -12.734094        00 00
# 1 -14.478787 -13.832706       00 000
# 2 -13.562496 -13.832706     00 00pay
# 3 -14.478787 -13.832706  00 00please
# 4 -15.171934 -13.832706      00 00pm

# %%
feature_importance['ratio'] = feature_importance[1] / feature_importance[0]
feature_importance.sort_values('ratio', axis=0, ascending=True, inplace=True)
feature_importance.head(20)
# Out:
#                 0          1  \
# 37941  -15.171934  -9.079116
# 61549  -15.171934  -9.556040
# 1133   -15.171934  -9.643051
# 104151 -15.171934  -9.643051
# 623501 -15.171934  -9.643051
# 487007 -15.171934  -9.643051
# 843638 -15.171934  -9.643051
# 581618 -15.171934  -9.643051
# 657527 -15.171934  -9.643051
# 573517 -15.171934  -9.643051
# 317210 -15.171934  -9.643051
# 448882 -15.171934  -9.738361
# 835347 -15.171934  -9.940886
# 348731 -14.478787  -9.556040
# 639508 -14.478787  -9.628013
# 238435 -14.478787  -9.643051
# 60798  -14.478787  -9.643051
# 559669 -15.171934 -10.143826
# 56435  -15.171934 -10.169144
# 890334 -15.171934 -10.169144
#
#                                                     words     ratio
# 37941                                       aker solution  0.598415
# 61549                                      aptitude staff  0.629850
# 1133    0fa3f7c5e23a16de16a841e368006cae916884407d90b1...  0.635585
# 104151                                    bring discovery  0.635585
# 623501                                production maximize  0.635585
# 487007                                  maximize recovery  0.635585
# 843638  url 0fa3f7c5e23a16de16a841e368006cae916884407d...  0.635585
# 581618                                    petroleum field  0.635585
# 657527                                 recovery petroleum  0.635585
# 573517                                          people 30  0.635585
# 317210                                       field employ  0.635585
# 448882                                    leverage career  0.641867
# 835347                                       ultra luxury  0.655215
# 348731                                    global provider  0.660003
# 639508                                   provider product  0.664974
# 238435                               discovery production  0.666012
# 60798                                    approximately 28  0.666012
# 559669                              overviewaker solution  0.668592
# 56435                               application onlyclick  0.670260
# 890334                                        year access  0.670260
